# %%
import pandas as pd
import numpy as np

df=pd.read_excel("/content/NBFCsandARCs10012023 (5).XLSX")
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#   SR No.                                          NBFC Name Regional Office  \
# 0      1                      Aditya Birla Finance Limited*       Ahmedabad
# 1      2                                 Bajaj Finance Ltd.          Mumbai
# 2      3  Cholamandalam Investment and Finance Company L...         Chennai
# 3      4                     HDB Financial Services Limited       Ahmedabad
# 4      5  L&T Finance Limited (Formerly known as L&T Fin...          Mumbai
#
#   Whether have CoR for holding/ Accepting Public Deposits Classification  \
# 0                                                 No                 ICC
# 1                                                Yes                 ICC
# 2                                                 No                 ICC
# 3                                                 No                 ICC
# 4                                                 No                 CIC
#
#   Corporate Identification Number  Layer  \
# 0           U65990GJ1991PLC064603  Upper
# 1           L65910MH1987PLC042961  Upper
# 2           L65993TN1978PLC007576  Upper
# 3           U65993GJ2007PLC051028  Upper
# 4           L67120MH2008PLC181833  Upper
#
#                                              Address  \
# 0  Indian Rayon Compound Veraval Gir Somnath Guja...
# 1                     Akurdi Pune Maharashtra 411035
# 2  Dare House, No. 2, NSC Bose Road, Parrys, Chen...
# 3  Radhika, 2nd Floor Law Garden Road, Navrangpur...
# 4  Brindavan, Plot No. 177, C. S. T Road, Kalina,...
#
#                                 Email ID Unnamed: 9
# 0  jitendra.bhati@adityabirlacapital.com        NaN
# 1                 wecare@bajajfinserv.in        NaN
# 2               gro@chola1.murugappa.com        NaN
# 3             dipti.khandelwal@hdbfs.com        NaN
# 4                   secretarial@ltfs.com        NaN

# %%
df.describe().loc['count']
# Out:
# SR No.                                                     9329
# NBFC Name                                                  9327
# Regional Office                                            9327
# Whether have CoR for holding/ Accepting Public Deposits    9327
# Classification                                             9327
# Corporate Identification Number                            9327
# Layer                                                      9327
# Address                                                    9327
# Email ID                                                   9327
# Unnamed: 9                                                    3
# Name: count, dtype: object

# %%
pip install serpapi
# Out:
# Collecting serpapi
#   Downloading serpapi-0.1.5-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from serpapi) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->serpapi) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->serpapi) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->serpapi) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->serpapi) (2024.7.4)
# Installing collected packages: serpapi
# Successfully installed serpapi-0.1.5

# %%
import serpapi
import os

# %%
def result(q,location):
  client=serpapi.Client(api_key=os.getenv("Serp_API"))
  result=client.search(
    q=q,
    engine="google",
    location=location,
    hl="en",
    gl="in",
    num="1"
 )
  for item in result['organic_results']:
    return (item['link'])

# %%
q=(df['NBFC Name'][0])
l=(df['Regional Office'][0])
result(q,l)
# Out:
# 'http://abfl.adityabirlacapital.com/Pages/Individual/About-Us/Company-Profile.aspx'

# %%
df['Official Website']=np.nan

# %%
limit=False
for index,row in df.iterrows():
  if limit==True:
    break

  if(pd.isna(df['NBFC Name'][index])==False):
    try:
      df['Official Website'][index]=result(df['NBFC Name'][index],df['Regional Office'][index])
      print("index ",index," found\n")

    except Exception as e:
      df['Official Website'][index]="data not available"
      if "429" in str(e):
        reason="search limit reached"
        limit=True
      if "500" in str(e):
        reason="Internal Server error"
      if "401" in str(e):
        reason="Unauthorised"
      if "402" in str(e):
        reason="Payment Required"
      if "404" in str(e):
        reason="Not Found"

      print("index ",index," not found due to ", reason)
  else:
    print("index ",index," not found due to missing data")
# Out:
# <ipython-input-9-c0ca654618cb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Official Website'][index]=result(df['NBFC Name'][index],df['Regional Office'][index])
# index  0  found
#
# index  1  found
#
# index  2  found
#
# index  3  found
#
# index  4  found
#
# index  5  found
#
# index  6  found
#
# index  7  found
#
# index  8  found
#
# index  9  found
#
# index  10  found
#
# index  11  found
#
# index  12  found
#
# index  13  found
#
# index  14  found
#
# index  15  found
#
# index  16  found
#
# index  17  found
#
# index  18  found
#
# index  19  found
#
# index  20  found
#
# index  21  found
#
# index  22  found
#
# index  23  found
#
# index  24  found
#
# index  25  found
#
# index  26  found
#
# index  27  found
#
# index  28  found
#
# index  29  found
#
# index  30  found
#
# index  31  found
#
# index  32  found
#
# index  33  found
#
# index  34  found
#
# index  35  found
#
# index  36  found
#
# index  37  found
#
# index  38  not found due to  search limit reached

# %%
df[df['NBFC Name'].isna()]
# Out:
#                                                  SR No. NBFC Name  \
# 9327                                                NaN       NaN
# 9328  * Additional CoR to commence and carry on Fact...       NaN
# 9329              CoR   -   Certificate of Registration       NaN
#
#      Regional Office Whether have CoR for holding/ Accepting Public Deposits  \
# 9327             NaN                                                NaN
# 9328             NaN                                                NaN
# 9329             NaN                                                NaN
#
#      Classification Corporate Identification Number Layer Address Email ID  \
# 9327            NaN                             NaN   NaN     NaN      NaN
# 9328            NaN                             NaN   NaN     NaN      NaN
# 9329            NaN                             NaN   NaN     NaN      NaN
#
#      Unnamed: 9 Official Website
# 9327        NaN              NaN
# 9328        NaN              NaN
# 9329        NaN              NaN

# %%
df2=pd.DataFrame()
df2['Regional Office']=df['Regional Office']
df2['NBFC Name']=df['NBFC Name']
df2['Address']=df['Address']
df2['Email ID']=df['Email ID']
df2['Official website']=df['Official Website']

df2.to_excel('output.xlsx',index=False)

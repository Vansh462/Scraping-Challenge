# %%
import pandas as pd
import numpy as np

df=pd.read_excel("/content/NBFCsandARCs10012023 (5).XLSX")
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
df.describe().loc['count']
# Out:
# SR No.                                                     9329
# NBFC Name                                                  9327
# Regional Office                                            9327
# Whether have CoR for holding/ Accepting Public Deposits    9327
# Classification                                             9327
# Corporate Identification Number                            9327
# Layer                                                      9327
# Address                                                    9327
# Email ID                                                   9327
# Unnamed: 9                                                    3
# Name: count, dtype: object

# %%
def safe_correction(x):
  try:
    return int(x)-1
  except:
    return 0

# %%
df['SR No.']=df['SR No.'].apply(lambda x: safe_correction(x))
df.head()
# Out:
#    SR No.                                          NBFC Name Regional Office  \
# 0       0                      Aditya Birla Finance Limited*       Ahmedabad
# 1       1                                 Bajaj Finance Ltd.          Mumbai
# 2       2  Cholamandalam Investment and Finance Company L...         Chennai
# 3       3                     HDB Financial Services Limited       Ahmedabad
# 4       4  L&T Finance Limited (Formerly known as L&T Fin...          Mumbai
#
#   Whether have CoR for holding/ Accepting Public Deposits Classification  \
# 0                                                 No                 ICC
# 1                                                Yes                 ICC
# 2                                                 No                 ICC
# 3                                                 No                 ICC
# 4                                                 No                 CIC
#
#   Corporate Identification Number  Layer  \
# 0           U65990GJ1991PLC064603  Upper
# 1           L65910MH1987PLC042961  Upper
# 2           L65993TN1978PLC007576  Upper
# 3           U65993GJ2007PLC051028  Upper
# 4           L67120MH2008PLC181833  Upper
#
#                                              Address  \
# 0  Indian Rayon Compound Veraval Gir Somnath Guja...
# 1                     Akurdi Pune Maharashtra 411035
# 2  Dare House, No. 2, NSC Bose Road, Parrys, Chen...
# 3  Radhika, 2nd Floor Law Garden Road, Navrangpur...
# 4  Brindavan, Plot No. 177, C. S. T Road, Kalina,...
#
#                                 Email ID Unnamed: 9  Official Website
# 0  jitendra.bhati@adityabirlacapital.com        NaN               NaN
# 1                 wecare@bajajfinserv.in        NaN               NaN
# 2               gro@chola1.murugappa.com        NaN               NaN
# 3             dipti.khandelwal@hdbfs.com        NaN               NaN
# 4                   secretarial@ltfs.com        NaN               NaN

# %%
from googlesearch import search
import time

class TooManyRequestsError(Exception):
    pass

def result(df,bank_name,index):
    index=int(index)
    query = f"{bank_name} official site"

    try:
        for url in search(query,num=1):
          df.at[index, 'Official Website'] = url
          print(f"Bank at index {index} found \n")
          return
    except Exception as e:
        print(f"An error occurred at index {index}: {e}")
        if "429" in str(e):
          raise TooManyRequestsError(e)
          return None

    return

# %%
#method 1- 0.26 s/ search
def process_banks(df, column_name='NBFC Name', result_column='Official Website'):
    df[result_column] = ''

    with ThreadPoolExecutor(max_workers=10) as executor:
        try:

            args = [(df, row[column_name], index) for index, row in df.iterrows()]

            list(executor.map(lambda p: result(*p), args))

        except TooManyRequestsError as e:
            print(f"Stopping execution due to error: {e}")

    return

# %%
#method 2- works better than method 1 but still errors
from multiprocessing import Pool

def process_banks(df,bank_names,indexes):
    arguments = list(zip(df,bank_names, indexes))

    with Pool(processes=20) as pool:
        pool.starmap(result,arguments)
    return "all done"

# %%
#method 3- ignore it
def result(bank_name):

    query = f"{bank_name} official site"

    try:
        for url in search(query,num=1):
          return url
    except Exception as e:
        print(f"An error occurred: {e}")

    return None

from concurrent.futures import ThreadPoolExecutor
def process_banks(bank_names, delay=2):
    results = []
    with ThreadPoolExecutor(max_workers=10) as executor:  # Adjust max_workers as needed
        for i in range(0, len(bank_names), 100):  # Process in batches of 100
            batch = bank_names[i:i + 100]
            batch_results = list(executor.map(result, batch))
            results.extend(batch_results)
            print(f"Processed batch {i // 100 + 1}")
            time.sleep(delay)  # Sleep to avoid hitting rate limits
    return results
# Out:
#   File "<ipython-input-10-39b1dbc71bcc>", line 3
#     query = f"{bank_name} official site"
#     ^
# IndentationError: unexpected indent

# %%
process_banks(df)
# Out:
# Bank at index 1 found
#
# Bank at index 8 found
#
# Bank at index 0 found
#
# Bank at index 2 found
# Bank at index 7 found
#
#
# Bank at index 4 found
# Bank at index 6 found
#
#
# Bank at index 3 found
#
# Bank at index 5 found
#
# Bank at index 9 found
#
# Bank at index 12 found
#
# Bank at index 10 found
#
# Bank at index 13 found
#
# Bank at index 18 found
#
# Bank at index 11 found
#
# Bank at index 16 found
#
# Bank at index 14 found
# Bank at index 15 found
#
#
# Bank at index 17 found
#
# Bank at index 19 found
#
# Bank at index 20 found
#
# Bank at index 25 found
#
# Bank at index 26 found
#
# Bank at index 27 found
#
# Bank at index 23 found
#
# Bank at index 22 found
# Bank at index 24 found
#
#
# Bank at index 28 found
#
# Bank at index 21 found
#
# Bank at index 29 found
#
# Bank at index 30 found
#
# Bank at index 32 found
#
# Bank at index 34 found
#
# Bank at index 36 found
#
# Bank at index 33 found
#
# Bank at index 35 found
#
# Bank at index 37 found
#
# Bank at index 31 found
#
# Bank at index 38 found
#
# Bank at index 39 found
#
# Bank at index 40 found
#
# Bank at index 43 found
#
# Bank at index 44 found
#
# Bank at index 42 found
#
# Bank at index 45 found
#
# Bank at index 41 found
#
# Bank at index 47 found
#
# Bank at index 49 found
#
# Bank at index 46 found
#
# Bank at index 48 found
#
# Bank at index 51 found
# Bank at index 50 found
#
#
# Bank at index 55 found
#
# Bank at index 53 found
#
# Bank at index 56 found
# Bank at index 52 found
#
#
# Bank at index 57 found
# Bank at index 58 found
#
#
# Bank at index 54 found
#
# Bank at index 59 found
#
# Bank at index 60 found
#
# Bank at index 61 found
#
# Bank at index 62 found
#
# Bank at index 63 found
#
# Bank at index 65 found
#
# Bank at index 67 found
#
# Bank at index 64 found
#
# Bank at index 66 found
#
# Bank at index 68 found
#
# Bank at index 69 found
#
# Bank at index 72 found
#
# Bank at index 70 found
#
# Bank at index 71 found
#
# Bank at index 74 found
#
# Bank at index 78 found
#
# Bank at index 76 found
#
# Bank at index 75 found
#
# Bank at index 77 found
#
# Bank at index 73 found
#
# Bank at index 79 found
#
# Bank at index 80 found
#
# Bank at index 82 found
#
# Bank at index 85 found
#
# Bank at index 81 found
#
# Bank at index 87 found
#
# Bank at index 86 found
#
# Bank at index 89 found
#
# Bank at index 84 found
#
# Bank at index 83 found
#
# Bank at index 88 found
#
# Bank at index 90 found
#
# Bank at index 91 found
#
# Bank at index 93 found
#
# Bank at index 94 found
#
# Bank at index 92 found
#
# Bank at index 96 found
#
# Bank at index 95 found
#
# Bank at index 97 found
#
# Bank at index 98 found
#
# Bank at index 99 found
#
# Bank at index 100 found
#
# Bank at index 101 found
#
# Bank at index 102 found
#
# Bank at index 103 found
#
# Bank at index 104 found
#
# Bank at index 106 found
# Bank at index 107 found
#
#
# Bank at index 108 found
#
# Bank at index 109 found
#
# Bank at index 105 found
#
# Bank at index 110 found
#
# Bank at index 111 found
#
# Bank at index 112 found
#
# Bank at index 113 found
#
# Bank at index 114 found
#
# Bank at index 117 found
#
# Bank at index 115 found
#
# Bank at index 116 found
#
# Bank at index 118 found
#
# Bank at index 119 found
#
# Bank at index 120 found
#
# Bank at index 121 found
#
# Bank at index 124 found
#
# Bank at index 123 found
#
# Bank at index 122 found
#
# Bank at index 125 found
#
# Bank at index 126 found
#
# Bank at index 127 found
#
# Bank at index 128 found
#
# Bank at index 129 found
#
# Bank at index 130 found
#
# Bank at index 134 found
#
# Bank at index 131 found
#
# Bank at index 132 found
#
# Bank at index 133 found
#
# Bank at index 135 found
#
# Bank at index 136 found
#
# Bank at index 138 found
#
# Bank at index 137 found
#
# Bank at index 139 found
#
# Bank at index 140 found
#
# Bank at index 141 found
#
# Bank at index 142 found
#
# Bank at index 143 found
#
# Bank at index 144 found
#
# Bank at index 147 found
#
# Bank at index 145 found
#
# Bank at index 148 found
#
# Bank at index 146 found
#
# Bank at index 149 found
#
# Bank at index 150 found
#
# Bank at index 151 found
#
# Bank at index 152 found
#
# Bank at index 154 found
#
# Bank at index 153 found
#
# Bank at index 155 found
# Bank at index 157 found
# Bank at index 156 found
#
# Bank at index 158 found
#
#
#
# Bank at index 159 found
#
# Bank at index 164 found
#
# Bank at index 165 found
#
# Bank at index 167 found
#
# Bank at index 169 found
#
# Bank at index 162 found
#
# Bank at index 166 found
#
# Bank at index 168 found
#
# Bank at index 160 found
#
# Bank at index 161 found
#
# Bank at index 163 found
#
# Bank at index 170 found
#
# Bank at index 176 found
#
# Bank at index 172 found
#
# Bank at index 174 found
#
# Bank at index 171 found
#
# Bank at index 175 found
#
# Bank at index 173 found
#
# Bank at index 178 found
#
# Bank at index 177 found
#
# Bank at index 179 found
#
# Bank at index 180 found
#
# Bank at index 184 found
#
# Bank at index 181 found
#
# Bank at index 182 found
#
# Bank at index 183 found
#
# Bank at index 189 found
#
# Bank at index 185 found
#
# Bank at index 187 found
#
# Bank at index 186 found
#
# Bank at index 188 found
#
# Bank at index 190 found
#
# Bank at index 197 found
#
# Bank at index 191 found
#
# Bank at index 192 found
#
# Bank at index 193 found
#
# Bank at index 196 found
#
# Bank at index 194 found
#
# Bank at index 195 found
#
# Bank at index 198 found
#
# Bank at index 199 found
#
# Bank at index 200 found
#
# Bank at index 202 found
#
# Bank at index 207 found
#
# Bank at index 205 found
#
# Bank at index 201 found
#
# Bank at index 203 found
#
# Bank at index 206 found
#
# Bank at index 204 found
#
# Bank at index 209 found
#
# Bank at index 208 found
#
# Bank at index 210 found
#
# Bank at index 211 found
#
# Bank at index 213 found
#
# Bank at index 212 found
#
# Bank at index 214 found
#
# Bank at index 215 found
#
# Bank at index 219 found
#
# Bank at index 217 found
#
# Bank at index 218 found
#
# Bank at index 216 found
#
# Bank at index 220 found
#
# Bank at index 221 found
#
# Bank at index 223 found
#
# Bank at index 222 found
#
# Bank at index 225 found
#
# Bank at index 224 found
#
# Bank at index 226 found
#
# Bank at index 228 found
#
# Bank at index 227 found
#
# Bank at index 229 found
#
# Bank at index 230 found
#
# Bank at index 234 found
#
# Bank at index 231 found
#
# Bank at index 232 found
#
# Bank at index 233 found
#
# Bank at index 237 found
#
# Bank at index 235 found
#
# Bank at index 236 found
#
# Bank at index 238 found
#
# Bank at index 239 found
#
# Bank at index 240 found
#
# Bank at index 242 found
#
# Bank at index 241 found
#
# Bank at index 244 found
#
# Bank at index 243 found
#
# Bank at index 247 found
#
# Bank at index 246 found
#
# Bank at index 248 found
#
# Bank at index 245 found
#
# Bank at index 249 found
#
# Bank at index 250 found
#
# Bank at index 251 found
#
# Bank at index 253 found
#
# Bank at index 252 found
#
# Bank at index 258 found
#
# Bank at index 254 found
#
# Bank at index 255 found
#
# Bank at index 257 found
#
# Bank at index 256 found
#
# Bank at index 259 found
#
# Bank at index 260 found
#
# Bank at index 262 found
#
# Bank at index 261 found
#
# Bank at index 263 found
#
# Bank at index 268 found
#
# Bank at index 264 found
#
# Bank at index 265 found
#
# Bank at index 267 found
#
# Bank at index 266 found
#
# Bank at index 269 found
#
# Bank at index 270 found
#
# Bank at index 272 found
#
# Bank at index 271 found
#
# Bank at index 274 found
#
# Bank at index 273 found
#
# Bank at index 278 found
#
# Bank at index 275 found
#
# Bank at index 277 found
#
# Bank at index 276 found
#
# Bank at index 279 found
#
# Bank at index 281 found
#
# Bank at index 280 found
#
# Bank at index 284 found
#
# Bank at index 282 found
#
# Bank at index 285 found
#
# Bank at index 283 found
#
# Bank at index 289 found
#
# Bank at index 287 found
#
# Bank at index 286 found
#
# Bank at index 288 found
#
# Bank at index 291 found
#
# Bank at index 290 found
#
# Bank at index 293 found
#
# Bank at index 292 found
#
# Bank at index 294 found
#
# Bank at index 295 found
#
# Bank at index 297 found
#
# Bank at index 299 found
#
# Bank at index 296 found
#
# Bank at index 298 found
#
# Bank at index 300 found
#
# Bank at index 303 found
#
# Bank at index 305 found
#
# Bank at index 301 found
#
# Bank at index 302 found
#
# Bank at index 306 found
#
# Bank at index 304 found
#
# Bank at index 307 found
#
# Bank at index 308 found
#
# Bank at index 310 found
#
# Bank at index 311 found
#
# Bank at index 309 found
#
# Bank at index 313 found
#
# Bank at index 316 found
#
# Bank at index 312 found
#
# Bank at index 314 found
#
# Bank at index 315 found
#
# Bank at index 321 found
#
# Bank at index 318 found
#
# Bank at index 317 found
#
# Bank at index 322 found
#
# Bank at index 320 found
#
# Bank at index 319 found
#
# Bank at index 325 found
#
# Bank at index 326 found
#
# Bank at index 324 found
#
# Bank at index 323 found
#
# Bank at index 327 found
#
# Bank at index 329 found
#
# Bank at index 330 found
#
# Bank at index 328 found
#
# Bank at index 331 found
#
# Bank at index 332 found
#
# Bank at index 334 found
#
# Bank at index 333 found
#
# Bank at index 336 found
#
# Bank at index 335 found
#
# Bank at index 339 found
#
# Bank at index 337 found
#
# Bank at index 338 found
#
# Bank at index 342 found
#
# Bank at index 343 found
#
# Bank at index 341 found
#
# Bank at index 340 found
#
# Bank at index 344 found
#
# Bank at index 345 found
#
# Bank at index 349 found
#
# Bank at index 346 found
#
# Bank at index 347 found
#
# Bank at index 348 found
#
# Bank at index 352 found
#
# Bank at index 351 found
#
# Bank at index 350 found
#
# Bank at index 353 found
#
# Bank at index 354 found
#
# Bank at index 355 found
#
# Bank at index 356 found
#
# Bank at index 358 found
#
# Bank at index 357 found
#
# Bank at index 360 found
#
# Bank at index 359 found
#
# Bank at index 361 found
#
# Bank at index 362 found
#
# Bank at index 363 found
#
# Bank at index 364 found
#
# Bank at index 365 found
#
# Bank at index 367 found
#
# Bank at index 370 found
#
# Bank at index 368 found
#
# Bank at index 366 found
#
# Bank at index 373 found
#
# Bank at index 372 found
#
# Bank at index 371 found
#
# Bank at index 369 found
#
# Bank at index 374 found
#
# Bank at index 375 found
#
# Bank at index 376 found
#
# Bank at index 380 found
#
# Bank at index 383 found
#
# Bank at index 378 found
#
# Bank at index 377 found
#
# Bank at index 384 found
#
# Bank at index 381 found
#
# Bank at index 379 found
#
# Bank at index 382 found
#
# Bank at index 386 found
#
# Bank at index 385 found
#
# Bank at index 388 found
#
# Bank at index 387 found
#
# Bank at index 391 found
#
# Bank at index 394 found
#
# Bank at index 393 found
#
# Bank at index 389 found
#
# Bank at index 390 found
#
# Bank at index 392 found
#
# Bank at index 395 found
#
# Bank at index 396 found
#
# Bank at index 397 found
#
# Bank at index 401 found
#
# Bank at index 402 found
#
# Bank at index 403 found
#
# Bank at index 404 found
#
# Bank at index 398 found
#
# Bank at index 400 found
#
# Bank at index 399 found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-f6ddd13413e5> in process_banks(df, column_name, result_column)
#       9
# ---> 10             list(executor.map(lambda p: result(*p), args))
#      11
#
# /usr/lib/python3.10/concurrent/futures/_base.py in result_iterator()
#     620                     if timeout is None:
# --> 621                         yield _result_or_cancel(fs.pop())
#     622                     else:
#
# /usr/lib/python3.10/concurrent/futures/_base.py in _result_or_cancel(***failed resolving arguments***)
#     318         try:
# --> 319             return fut.result(timeout)
#     320         finally:
#
# /usr/lib/python3.10/concurrent/futures/_base.py in result(self, timeout)
#     452
# --> 453                 self._condition.wait(timeout)
#     454
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     319             if timeout is None:
# --> 320                 waiter.acquire()
#     321                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-dcd421f0c3f7> in <cell line: 1>()
# ----> 1 process_banks(df)
#
# <ipython-input-41-f6ddd13413e5> in process_banks(df, column_name, result_column)
#       3     df[result_column] = ''
#       4
# ----> 5     with ThreadPoolExecutor(max_workers=10) as executor:
#       6         try:
#       7
#
# /usr/lib/python3.10/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     647
#     648     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649         self.shutdown(wait=True)
#     650         return False
#     651
#
# /usr/lib/python3.10/concurrent/futures/thread.py in shutdown(self, wait, cancel_futures)
#     233         if wait:
#     234             for t in self._threads:
# --> 235                 t.join()
#     236     shutdown.__doc__ = _base.Executor.shutdown.__doc__
#
# /usr/lib/python3.10/threading.py in join(self, timeout)
#    1094
#    1095         if timeout is None:
# -> 1096             self._wait_for_tstate_lock()
#    1097         else:
#    1098             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.10/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1114
#    1115         try:
# -> 1116             if lock.acquire(block, timeout):
#    1117                 lock.release()
#    1118                 self._stop()
#
# KeyboardInterrupt:

# %%
df.head()
# Out:
#    SR No.                                          NBFC Name Regional Office  \
# 0       0                      Aditya Birla Finance Limited*       Ahmedabad
# 1       1                                 Bajaj Finance Ltd.          Mumbai
# 2       2  Cholamandalam Investment and Finance Company L...         Chennai
# 3       3                     HDB Financial Services Limited       Ahmedabad
# 4       4  L&T Finance Limited (Formerly known as L&T Fin...          Mumbai
#
#   Whether have CoR for holding/ Accepting Public Deposits Classification  \
# 0                                                 No                 ICC
# 1                                                Yes                 ICC
# 2                                                 No                 ICC
# 3                                                 No                 ICC
# 4                                                 No                 CIC
#
#   Corporate Identification Number  Layer  \
# 0           U65990GJ1991PLC064603  Upper
# 1           L65910MH1987PLC042961  Upper
# 2           L65993TN1978PLC007576  Upper
# 3           U65993GJ2007PLC051028  Upper
# 4           L67120MH2008PLC181833  Upper
#
#                                              Address  \
# 0  Indian Rayon Compound Veraval Gir Somnath Guja...
# 1                     Akurdi Pune Maharashtra 411035
# 2  Dare House, No. 2, NSC Bose Road, Parrys, Chen...
# 3  Radhika, 2nd Floor Law Garden Road, Navrangpur...
# 4  Brindavan, Plot No. 177, C. S. T Road, Kalina,...
#
#                                 Email ID Unnamed: 9  \
# 0  jitendra.bhati@adityabirlacapital.com        NaN
# 1                 wecare@bajajfinserv.in        NaN
# 2               gro@chola1.murugappa.com        NaN
# 3             dipti.khandelwal@hdbfs.com        NaN
# 4                   secretarial@ltfs.com        NaN
#
#                                     Official Website
# 0  http://abfl.adityabirlacapital.com/Pages/Indiv...
# 1                       https://www.bajajfinserv.in/
# 2                     https://www.cholamandalam.com/
# 3                             https://www.hdbfs.com/
# 4                              https://www.ltfs.com/

# %%
df['Official Website'][304]
# Out:
# 'http://reliancefinancial.co.in/'

# %%
df['NBFC Name'][304]
# Out:
# 'Reliance Commercial Finance Limited (Formerly known as Reliance Gilts Ltd.)'

# %%
df.to_excel("output.xlsx")
